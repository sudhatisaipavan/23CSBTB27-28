# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhatisaipavan/23CSBTB27-28/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
s = pd.Series([12,1,5,3,2])
print(s)

ds1 = pd.Series([2, 4, 6, 8, 10])
ds2 = pd.Series([1, 3, 5, 7, 9])
print("sum of series elements")
ds = ds1 + ds2
print(ds)

ds1 = pd.Series([2, 4, 6, 8, 10])
ds2 = pd.Series([1, 3, 5, 7, 9])
print("multiply of series elements")
ds = ds1 * ds2
print(ds)
# Out:
# Mounted at /content/drive
# 0    12
# 1     1
# 2     5
# 3     3
# 4     2
# dtype: int64
# sum of series elements
# 0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64
# multiply of series elements
# 0     2
# 1    12
# 2    30
# 3    56
# 4    90
# dtype: int64

# %%
import pandas as pd
from google.colab import files
my_path = '/content/banklist.csv'
data = pd.read_csv(my_path)
data.head()
# Out:
#                                   Bank Name          City  ST   CERT  \
# 0  Banks of Wisconsin d/b/a Bank of Kenosha       Kenosha  WI  35386
# 1                      Central Arizona Bank    Scottsdale  AZ  34527
# 2                              Sunrise Bank      Valdosta  GA  58185
# 3                     Pisgah Community Bank     Asheville  NC  58701
# 4                       Douglas County Bank  Douglasville  GA  21649
#
#    Acquiring Institution Closing Date Updated Date
# 0  North Shore Bank, FSB    31-May-13    31-May-13
# 1     Western State Bank    14-May-13    20-May-13
# 2           Synovus Bank    10-May-13    21-May-13
# 3     Capital Bank, N.A.    10-May-13    14-May-13
# 4    Hamilton State Bank    26-Apr-13    16-May-13

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
data=pd.read_csv('banklist.csv')
data.head()
# Out:
#      <input type="file" id="files-e926ccfd-8e20-459b-b963-6ca2654f7e8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e926ccfd-8e20-459b-b963-6ca2654f7e8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
data=pd.read_csv('banklist.csv')
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-034dd884-68c1-4c0d-aef2-e7cf2d9a1d02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-034dd884-68c1-4c0d-aef2-e7cf2d9a1d02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
data=pd.read_csv('titanic.csv')
print(data.isnull().sum())
data['Age'].fillna(data['Age'].median(), inplace=True)
print(data.isnull().sum())
# Out:
#      <input type="file" id="files-dbf3bb3d-ee39-4084-9450-8bb91049f987" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbf3bb3d-ee39-4084-9450-8bb91049f987">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
